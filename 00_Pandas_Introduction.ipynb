# %% [markdown]
# **CLASE DE INTRODUCCIÓN AL MACHINE LEARNING AUTO 1 - EDA pandas**
#
# **POR:** Yomin Jaramillo Múnera
#
#
# **BASADO EN:**
#
# https://towardsdatascience.com/an-introduction-to-pandas-29d15a7da6d
#
# https://pandas.pydata.org/docs/user_guide/index.html

# %% [markdown]
# Pandas es un paquete especializado que permite hacer el analisis de datos y nos facilita el trabajo con bases de datos externas. Es una herramienta popular para abordar el  análisis exploratorio de datos - EDA (EXploratory Data Analysis)

# %%
import pandas as pd # como numpy generalmente se abrevia como np, por lo general pandas se abrevia como pd

# %% [markdown]
# La principal aplicación de pandas es el trabajo con Dataframes, los cuales son definidos como: Datos tabulares bidimensionales, de tamaño variable y potencialmente heterogéneos.La estructura de datos también contiene ejes etiquetados (filas y columnas).
# El dataframe es la principal estructura de datos de pandas.
#
# Por lo tanto hablamos de una estructura de datos bidimensional (comparable con una matriz), con la diferencia que los tipos de datos en la estructura puede ser diferente. Al igual que la matriz, se organiza en filas y columnas.

# %% [markdown]
# **CREACIÓN DE UN DATAFRAME**
#
# En general, existen multiples formas de crear un Dataframe, desde una lista, desde un diccionario, desde un array de numpy o incluso se pueden importar archivos externos como .csv, .xls, o sql

# %%
#Desde una lista
Animes_favoritos = [['Shingeki no Kyogin', 'Eren', "Shonen"], ['Naruto', 'Naruto'], ['Death note', 'Yagami',"Shonen"],["One Piece"], ["Saint Seiya", "Seiya", "Shonen", "4", "Athenea"]]
df_animes = pd.DataFrame(Animes_favoritos)
df_animes
# Out:
#                     0       1       2     3        4
# 0  Shingeki no Kyogin    Eren  Shonen  None     None
# 1              Naruto  Naruto    None  None     None
# 2          Death note  Yagami  Shonen  None     None
# 3           One Piece    None    None  None     None
# 4         Saint Seiya   Seiya  Shonen     4  Athenea

# %%
#Desde un diccionario
dict1 = {'Exercises': ['Running','Walking','Cycling'],
         'Mileage': [250, 1000, 550]}
df = pd.DataFrame(dict1)
df
# Out:
#   Exercises  Mileage
# 0   Running      250
# 1   Walking     1000
# 2   Cycling      550

# %% [markdown]
# **EJERCICIO 1:** Construir un Dataframe a partir de un array de numpy

# %% [markdown]
# **IMPORTAR BASES DE DATOS**
#
# A pesar de que hay varias metodologías para la creación de Dataframes, como las vistas anteriormente, es muy común que se haga la importación de base de datos externas.
# En general, teniendo en cuenta la gran acogida de pandas como framework de análisis de datos, varios formatos pueden ser convertidos usando el pd.
# Recomiendo seguir la documentación oficial disponible según la necesidad que tenga:
#
# https://pandas.pydata.org/docs/user_guide/index.html
#
# Normalmente el archivo de la base de datos externa es ubicado en la misma carpeta del script de python o el notebook desde el que se va a llamar. En este notebook se trabajo con un archivo con extensión ".csv" el cual se ubico en la misma carpeta que este notebook.
#
# Para la sincronización del notebook con google drive se ejecuta lo siguiente:

# %%
from google.colab import drive
import sys
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# El codigo les solicitará una autenticación para sincronizar los datos de su drive al noteebok presente. Una vez alli el folder de la barra del menú a la izquierda le debe aparecer una carpeta llamada Drive, lo cual indíca la sincronización de la información.
# Despliegue la carpeta de Drive y busque la ubicación donde se alojan el notebook y la base de datos,  posteriormente, copie el path y corra el siguiente codigo para ubicarse directamente en dicha carpeta

# %%
#sys.path.append('/content/drive/MyDrive/Colab Notebooks/Auto 1')
# %cd '/content/drive/MyDrive/Colab Notebooks/Auto 1'
#puede confirmar su ubiación mediante:
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/Auto 1
#  bmi.csv                               Matplotlib_introduction.ipynb
# 'Clasificacion cardiacas.ipynb'       'Metricas de clasificacion.ipynb'
#  Class3and4_Operations.ipynb          'Normalization Introduction.ipynb'
#  cricketer.csv                         Pandas_Introduction.ipynb
#  Data.csv                             'Parcial 1'/
#  EMG-data.csv                          Perceptron_full.ipynb
#  Final/                                Perceptron.ipynb
#  heart.csv                             RegresionLineal-MultiVariables.ipynb
#  IntroductionPerceptron_simple.ipynb   RegresionLinealSimple.ipynb
# 'Laboratorio 1'/                       Untitled0.ipynb
# 'Laboratorio 2'/                       Untitled1.ipynb
# 'Laboratorio final'/                   Variables.ipynb
#  LinearClassifiers.ipynb               Vectores_Matrices_Tensores.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Una vez en la ubicación, podemos hacer la lectura de la base de datos. En este caso se va a trabajar con cricker.csv por lo que se usa el método read_csv, pero recuerde que puede varia según el archivo que desee importar

# %%
df=pd.read_csv('cricketer.csv')
df
# Out:
#       Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 0              1  right  1890   102     0    0    0      0  alive
# 1              2   left  1892   100     0    0    0      0  alive
# 2              3  right  1893    99     0    0    0      0  alive
# 3              4  right  1894    98     0    0    0      0  alive
# 4              5  right  1896    96     0    0    0      0  alive
# ...          ...    ...   ...   ...   ...  ...  ...    ...    ...
# 5955        6168  right  1890    46     1    0    0      1  inbed
# 5956        6169  right  1919    63     1    0    0      1  inbed
# 5957        6170   left  1876    88     1    0    0      1  inbed
# 5958        6171   left  1850    65     1    0    0      1  inbed
# 5959        6172   left  1885    32     1    1    1      0    acd
#
# [5960 rows x 9 columns]

# %%
# Out:
#       Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 0              1  right  1890   102     0    0    0      0  alive
# 2              3  right  1893    99     0    0    0      0  alive
# 3              4  right  1894    98     0    0    0      0  alive
# 4              5  right  1896    96     0    0    0      0  alive
# 5              6  right  1896    96     0    0    0      0  alive
# ...          ...    ...   ...   ...   ...  ...  ...    ...    ...
# 5952        6165  right  1856    69     1    0    0      1  inbed
# 5953        6166  right  1876    37     1    0    0      1  inbed
# 5954        6167  right  1867    80     1    0    0      1  inbed
# 5955        6168  right  1890    46     1    0    0      1  inbed
# 5956        6169  right  1919    63     1    0    0      1  inbed
#
# [4859 rows x 9 columns]

# %% [markdown]
# **PRIMEROS PASOS**
#
# Es ideal hacer una visualización general de los datos para familiarizarse con ellos y estudiar la composición de la base de datos. Para esto se recomienda el uso de algunos de los siguientes métodos:

# %%
df.head() #toma las 5 primeras muestras de la base de datos
# Out:
#    Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 0           1  right  1890   102     0    0    0      0  alive
# 1           2   left  1892   100     0    0    0      0  alive
# 2           3  right  1893    99     0    0    0      0  alive
# 3           4  right  1894    98     0    0    0      0  alive
# 4           5  right  1896    96     0    0    0      0  alive

# %%
df.tail() #toma las ultimas 5 muestras de la base de datos
# Out:
#       Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 5955        6168  right  1890    46     1    0    0      1  inbed
# 5956        6169  right  1919    63     1    0    0      1  inbed
# 5957        6170   left  1876    88     1    0    0      1  inbed
# 5958        6171   left  1850    65     1    0    0      1  inbed
# 5959        6172   left  1885    32     1    1    1      0    acd

# %%
df.info()#Muestra información general de la base de datos y tipos de datos de las columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5960 non-null   int64
#  1   left        5960 non-null   object
#  2   year        5960 non-null   int64
#  3   life        5960 non-null   int64
#  4   dead        5960 non-null   int64
#  5   acd         5960 non-null   int64
#  6   kia         5960 non-null   int64
#  7   inbed       5960 non-null   int64
#  8   cause       5960 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 419.2+ KB

# %%
df.describe()#muestra descripción estadistica de los datos
# Out:
#         Unnamed: 0         year         life         dead          acd  \
# count  5960.000000  5960.000000  5960.000000  5960.000000  5960.000000
# mean   3035.931879  1905.639430    61.836913     0.568289     0.031544
# std    1783.262498    33.042651    16.602504     0.495356     0.174796
# min       1.000000  1840.000000    19.000000     0.000000     0.000000
# 25%    1490.750000  1878.000000    49.000000     0.000000     0.000000
# 50%    2992.000000  1908.000000    63.000000     1.000000     0.000000
# 75%    4579.250000  1935.000000    76.000000     1.000000     0.000000
# max    6172.000000  1960.000000   102.000000     1.000000     1.000000
#
#                kia        inbed
# count  5960.000000  5960.000000
# mean      0.020134     0.536745
# std       0.140471     0.498690
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     1.000000
# 75%       0.000000     1.000000
# max       1.000000     1.000000

# %%
df.sample(100).sort_values('life') #imprime una cantidad especifica de muestras de forma aleatoria
# Out:
#       Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 2668        2672  right  1864    26     1    0    0      1  inbed
# 4137        4224   left  1886    29     1    1    1      0    acd
# 4988        5137  right  1887    30     1    1    1      0    acd
# 3501        3543  right  1911    30     1    1    1      0    acd
# 3015        3029  right  1883    33     1    1    1      0    acd
# ...          ...    ...   ...   ...   ...  ...  ...    ...    ...
# 4389        4493   left  1889    89     1    0    0      1  inbed
# 3922        3993  right  1858    91     1    0    0      1  inbed
# 3039        3053   left  1866    91     1    0    0      1  inbed
# 4457        4566  right  1859    91     1    0    0      1  inbed
# 4265        4361  right  1881    94     1    0    0      1  inbed
#
# [100 rows x 9 columns]

# %%
df["cause"].unique()#define los posibles valores que puede tomar la columna 'cause'
# Out:
# array(['alive', 'inbed', 'acd'], dtype=object)

# %%
for i in df["cause"].unique():
  print(i)
# Out:
# alive
# inbed
# acd

# %%
for i in df["cause"]:
  print(i)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# alive
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# acd
# inbed
# acd
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# acd
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# inbed
# acd

# %% [markdown]
# **SELECCIÓN DE FILAS Y COLUMNAS**
#
# Para la referenciación de filas y/o columnas en un DataFrame se hace uso de .loc[  ] y .iloc[  ], el uso de uno  o de otro depende de la referenciación que usted desee hacer par acceder a la información.
#
# .loc[  ] se usa si usted conoce la etiqueta o nombre de la fila o columna.

# %%
df.loc[0:10,"year"]
basededatos=df.loc[0:100,["year", "left", "cause"]]

# %%
print(df.loc[10,:])
# Out:
# Unnamed: 0       11
# left          right
# year           1900
# life             92
# dead              0
# acd               0
# kia               0
# inbed             0
# cause         alive
# Name: 10, dtype: object

# %% [markdown]
# .iloc[  ] se usa para refenciase solo con los indices

# %%
df.iloc[15:18,5:]
# Out:
#     acd  kia  inbed  cause
# 15    0    0      0  alive
# 16    0    0      0  alive
# 17    0    0      0  alive

# %% [markdown]
# Tambien es posible combinar algunos de los métodos anteriores para tomar una porción especifica de datos:

# %%
df[['year','cause', 'dead']].head()
# Out:
#    year  cause  dead
# 0  1890  alive     0
# 1  1892  alive     0
# 2  1893  alive     0
# 3  1894  alive     0
# 4  1896  alive     0

# %%
df["year"]>=1920
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5955    False
# 5956    False
# 5957    False
# 5958    False
# 5959    False
# Name: year, Length: 5960, dtype: bool

# %% [markdown]
# \**EJERCICIO 2:** Importe una base de datos en formato .csv o desde excel y haga una familiarización con sus datos

# %% [markdown]
# **INSERTAR FILAS O COLUMNAS A UN DATAFRAME**
#
# Hay una gran variedad de formas de añadir filas y columnas en el dataframe, es posible hacer uso del .loc[  ] o tambien es posible utilizar .insert(). Es posible incluso hacer la concatenación de 2 dataframe usando pd.merge(), concat(), or join().
#
# Para nuestro ejemplo puntual, utilizaremos .iloc[ ] y .insert( ) para agregar nuevos datos.

# %%
print('Antes: \n', df.tail())
df.loc[5961]=[6173, 'right', 1994, 28, 0, 0, 0, None, 'alive']
print('Despues: \n', df.tail())
# Out:
# Antes:
#        Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 5955        6168  right  1890    46     1    0    0    1.0  inbed
# 5956        6169  right  1919    63     1    0    0    1.0  inbed
# 5957        6170   left  1876    88     1    0    0    1.0  inbed
# 5958        6171   left  1850    65     1    0    0    1.0  inbed
# 5959        6172   left  1885    32     1    1    1    0.0    acd
# Despues:
#        Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 5956        6169  right  1919    63     1    0    0    1.0  inbed
# 5957        6170   left  1876    88     1    0    0    1.0  inbed
# 5958        6171   left  1850    65     1    0    0    1.0  inbed
# 5959        6172   left  1885    32     1    1    1    0.0    acd
# 5961        6173  right  1994    28     0    0    0    NaN  alive
# <ipython-input-28-34d00e19b8d7>:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df.loc[5961]=[6173, 'right', 1994, 28, 0, 0, 0, None, 'alive']

# %% [markdown]
# Note que una nueva muestra o fila ha sido agregada al final del Dataframe. Adicionalmente, tenga en cuenta que en la adición del nuevo dato se definieron los valores de todas las columnas, no hacer esto generará un error, es preferible añadir la palabra None como indicador de la inexistencia del dato

# %%
print('Antes: \n', df.tail())
df.loc[5961]=[6174, 'right', 1965, 58, None, None, None, None, 'alive']
print('Despues: \n', df.tail())
# Out:
# Antes:
#        Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 5956        6169  right  1919    63     1    0    0    1.0  inbed
# 5957        6170   left  1876    88     1    0    0    1.0  inbed
# 5958        6171   left  1850    65     1    0    0    1.0  inbed
# 5959        6172   left  1885    32     1    1    1    0.0    acd
# 5961        6173  right  1994    28     0    0    0    NaN  alive
# Despues:
#        Unnamed: 0   left  year  life  dead  acd  kia  inbed  cause
# 5956        6169  right  1919    63   1.0  0.0  0.0    1.0  inbed
# 5957        6170   left  1876    88   1.0  0.0  0.0    1.0  inbed
# 5958        6171   left  1850    65   1.0  0.0  0.0    1.0  inbed
# 5959        6172   left  1885    32   1.0  1.0  1.0    0.0    acd
# 5961        6174  right  1965    58   NaN  NaN  NaN    NaN  alive

# %%
df.info()#Note que agregar valores None cambia la info de Non-Null Count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5961 entries, 0 to 5961
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5961 non-null   int64
#  1   left        5961 non-null   object
#  2   year        5961 non-null   int64
#  3   life        5961 non-null   int64
#  4   dead        5960 non-null   float64
#  5   acd         5960 non-null   float64
#  6   kia         5960 non-null   float64
#  7   inbed       5959 non-null   float64
#  8   cause       5961 non-null   object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 594.7+ KB

# %% [markdown]
# Tambien es posible insertar información que no necesariamente se ubique al final de las filas o columnas, en tal caso, puede usar .insert() el cual es aplicable en columnas

# %%
print('Antes: \n', df.tail())
df.insert(3,'new2_col', df["year"])#se definen 3 párametros, posición de inserción, nombre de la nueva columna, y valores(int, array o series de pandas)
print('Despues: \n', df.tail())
# Out:
# Antes:
#        Unnamed: 0   left  year  new_col  life  dead  acd  kia  inbed  cause
# 5955        6168  right  1890        1    46     1    0    0      1  inbed
# 5956        6169  right  1919        1    63     1    0    0      1  inbed
# 5957        6170   left  1876        1    88     1    0    0      1  inbed
# 5958        6171   left  1850        1    65     1    0    0      1  inbed
# 5959        6172   left  1885        1    32     1    1    1      0    acd
# Despues:
#        Unnamed: 0   left  year  new2_col  new_col  life  dead  acd  kia  inbed  \
# 5955        6168  right  1890      1890        1    46     1    0    0      1
# 5956        6169  right  1919      1919        1    63     1    0    0      1
# 5957        6170   left  1876      1876        1    88     1    0    0      1
# 5958        6171   left  1850      1850        1    65     1    0    0      1
# 5959        6172   left  1885      1885        1    32     1    1    1      0
#
#       cause
# 5955  inbed
# 5956  inbed
# 5957  inbed
# 5958  inbed
# 5959    acd

# %% [markdown]
# Tenga en cuenta que es posible agregar varios valores definiendo un nuevo DataFrame y utilizanto concat()
#
# **EJERCICIO 3:** Cree un DataFrame por el método que desee y concatenelo a nivel de filas a su Dataframe original. Use la documentación de pandas para investigar como usar el método.
#
# **ELIMINAR FILAS O COLUMNAS DE UN DATAFRAME**
#
# Para la eliminación de filas o columnas se hace uso de .Drop() debe especificar la posición sea por categora en caso de las columnas o por indice en el caso de las filas. Recuerde seleccionar el Axis. Si realizo el ejercicio 3 ya debe de tener claro que  se define 0 para filas y  1 para columnas

# %%
df=df.drop(labels='new_col',axis=1)#para eliminar la columna que añadimos
print(df)
# Out:
#       Unnamed: 0   left  year  life dead acd kia inbed  cause
# 0              1  right  1890   102    0   0   0     0  alive
# 1              2   left  1892   100    0   0   0     0  alive
# 2              3  right  1893    99    0   0   0     0  alive
# 3              4  right  1894    98    0   0   0     0  alive
# 4              5  right  1896    96    0   0   0     0  alive
# ...          ...    ...   ...   ...  ...  ..  ..   ...    ...
# 5955        6168  right  1890    46    1   0   0     1  inbed
# 5956        6169  right  1919    63    1   0   0     1  inbed
# 5957        6170   left  1876    88    1   0   0     1  inbed
# 5958        6171   left  1850    65    1   0   0     1  inbed
# 5959        6172   left  1885    32    1   1   1     0    acd
#
# [5960 rows x 9 columns]

# %%
df=df.drop(index=[5959, 5958],axis=0) #para eliminar las 2 filas añadidas
print(df)
# Out:
#       Unnamed: 0   left  year  life dead acd kia inbed  cause
# 0              1  right  1890   102    0   0   0     0  alive
# 1              2   left  1892   100    0   0   0     0  alive
# 2              3  right  1893    99    0   0   0     0  alive
# 3              4  right  1894    98    0   0   0     0  alive
# 4              5  right  1896    96    0   0   0     0  alive
# ...          ...    ...   ...   ...  ...  ..  ..   ...    ...
# 5953        6166  right  1876    37    1   0   0     1  inbed
# 5954        6167  right  1867    80    1   0   0     1  inbed
# 5955        6168  right  1890    46    1   0   0     1  inbed
# 5956        6169  right  1919    63    1   0   0     1  inbed
# 5957        6170   left  1876    88    1   0   0     1  inbed
#
# [5958 rows x 9 columns]

# %% [markdown]
# Tenga en cuenta que los 2 casos expuestos anteriormnente se hizo una asignación del retorno para actualizar df

# %% [markdown]
# **RENOMBRAR INDICES DE FILAS O LAS CATEGORIAS DE COLUMNAS**
#
# En ciertos casos puede llegar a ser necesario hacer un cambi de nombres para la referenciación de filas o columnas. En dado caso puede hacer uso del método .rename( )

# %%
print('Antes: \n', df.head())
df=df.rename(index={0:'first'}) #index cambia el valor indicado en la fila
df=df.rename(columns={'year':'years', })#columns cambia el nombre indicado de la columna
print('Despues: \n', df.head())
# Out:
# Antes:
#     Unnamed: 0   left  year  life dead acd kia inbed  cause
# 0           1  right  1890   102    0   0   0   0.0  alive
# 1           2   left  1892   100    0   0   0   0.0  alive
# 2           3  right  1893    99    0   0   0   0.0  alive
# 3           4  right  1894    98    0   0   0   0.0  alive
# 4           5  right  1896    96    0   0   0   0.0  alive
# Despues:
#         Unnamed: 0   left  years  life dead acd kia inbed  cause
# first           1  right   1890   102    0   0   0   0.0  alive
# 1               2   left   1892   100    0   0   0   0.0  alive
# 2               3  right   1893    99    0   0   0   0.0  alive
# 3               4  right   1894    98    0   0   0   0.0  alive
# 4               5  right   1896    96    0   0   0   0.0  alive

# %% [markdown]
# Nuevamente la actualización de df depende de la asignación.

# %% [markdown]
# **ITERACIONES EN UN DATAFRAMES**
#
# En ciertas ocasiones, puede ser necesario iterar a lo largo de todo el dataframe, las iteraciones a lo largo del dataframe pueden definirse como sigue:

# %%
for index, col in df.iterrows():
  print(index)
  print(col)
  print(type(col))
  break
  #print(col['life'])
# Out:
# 0
# Unnamed: 0        1
# left          right
# year           1890
# life            102
# dead              0
# acd               0
# kia               0
# inbed             0
# cause         alive
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Note que mientras index es un valor entero que hace referencia a la posición de la fila tomada, col es una serie de pandas que incluye todas los valores de columna para esa fila en particular.
# Una serie de pandas es una estructura unidimensional con etiquetas de eje (incluidas las series temporales).

# %% [markdown]
# **EJERCICIO 4:** haga un ciclo iterativo que le permita cambiar los valores de una columna con valores categoricos o objetos a simplemente números.
# Use condicionales y tenga en cuenta todos los posibles valores que pyuede tomar el dato en dicha columna para saber cuantos numeros deberia definir.
